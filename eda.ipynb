# %%
import fastf1
import pandas as pd

# %%
session = fastf1.get_session(2023, 'Bahrain', 'R')
session.load()
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (520.56 MB) /Users/nveshaan/Library/Caches/fastf1
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.7.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '14', '55', '44', '18', '63', '77', '10', '23', '22', '2', '20', '21', '27', '24', '4', '31', '16', '81']

# %%
# full width display for debugging
pd.set_option('display.max_columns', None)
session.results.head()
# Out:
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 1             1  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 11           11       S PEREZ          PER           perez  Red Bull Racing
# 14           14      F ALONSO          ALO          alonso     Aston Martin
# 55           55       C SAINZ          SAI           sainz          Ferrari
# 44           44    L HAMILTON          HAM        hamilton         Mercedes
#
#    TeamColor        TeamId FirstName    LastName         FullName  \
# 1     3671C6      red_bull       Max  Verstappen   Max Verstappen
# 11    3671C6      red_bull    Sergio       Perez     Sergio Perez
# 14    358C75  aston_martin  Fernando      Alonso  Fernando Alonso
# 55    F91536       ferrari    Carlos       Sainz     Carlos Sainz
# 44    6CD3BF      mercedes     Lewis    Hamilton   Lewis Hamilton
#
#                                           HeadshotUrl CountryCode  Position  \
# 1   https://www.formula1.com/content/dam/fom-websi...         NED       1.0
# 11  https://www.formula1.com/content/dam/fom-websi...         MEX       2.0
# 14  https://www.formula1.com/content/dam/fom-websi...         ESP       3.0
# 55  https://www.formula1.com/content/dam/fom-websi...         ESP       4.0
# 44  https://www.formula1.com/content/dam/fom-websi...         GBR       5.0
#
#    ClassifiedPosition  GridPosition  Q1  Q2  Q3                   Time  \
# 1                   1           1.0 NaT NaT NaT 0 days 01:33:56.736000
# 11                  2           2.0 NaT NaT NaT 0 days 00:00:11.987000
# 14                  3           5.0 NaT NaT NaT 0 days 00:00:38.637000
# 55                  4           4.0 NaT NaT NaT 0 days 00:00:48.052000
# 44                  5           7.0 NaT NaT NaT 0 days 00:00:50.977000
#
#       Status  Points  Laps
# 1   Finished    25.0  57.0
# 11  Finished    18.0  57.0
# 14  Finished    15.0  57.0
# 55  Finished    12.0  57.0
# 44  Finished    10.0  57.0

# %%
session.weather_data.head()
# Out:
#                     Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0 0 days 00:00:45.438000     29.8      19.0    1016.5     False       35.1
# 1 0 days 00:01:45.453000     29.7      19.0    1016.5     False       35.0
# 2 0 days 00:02:45.452000     29.7      19.0    1016.5     False       34.9
# 3 0 days 00:03:45.466000     29.6      19.0    1016.5     False       34.9
# 4 0 days 00:04:45.449000     29.6      19.0    1016.5     False       34.8
#
#    WindDirection  WindSpeed
# 0            176        1.2
# 1            182        1.2
# 2            156        1.1
# 3            201        0.8
# 4            219        0.8

# %%
session.laps.columns
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint',
#        'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate'],
#       dtype='object')

# %%
session.laps.head()
# Out:
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 01:04:15.902000    VER            1 0 days 00:01:39.019000
# 1 0 days 01:05:53.876000    VER            1 0 days 00:01:37.974000
# 2 0 days 01:07:31.882000    VER            1 0 days 00:01:38.006000
# 3 0 days 01:09:09.858000    VER            1 0 days 00:01:37.976000
# 4 0 days 01:10:47.893000    VER            1 0 days 00:01:38.035000
#
#    LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# 0        1.0    1.0        NaT       NaT                    NaT
# 1        2.0    1.0        NaT       NaT 0 days 00:00:31.342000
# 2        3.0    1.0        NaT       NaT 0 days 00:00:31.388000
# 3        4.0    1.0        NaT       NaT 0 days 00:00:31.271000
# 4        5.0    1.0        NaT       NaT 0 days 00:00:31.244000
#
#              Sector2Time            Sector3Time     Sector1SessionTime  \
# 0 0 days 00:00:42.414000 0 days 00:00:23.842000                    NaT
# 1 0 days 00:00:42.504000 0 days 00:00:24.128000 0 days 01:04:47.303000
# 2 0 days 00:00:42.469000 0 days 00:00:24.149000 0 days 01:06:25.323000
# 3 0 days 00:00:42.642000 0 days 00:00:24.063000 0 days 01:08:03.212000
# 4 0 days 00:00:42.724000 0 days 00:00:24.067000 0 days 01:09:41.161000
#
#       Sector2SessionTime     Sector3SessionTime  SpeedI1  SpeedI2  SpeedFL  \
# 0 0 days 01:03:52.119000 0 days 01:04:16.010000    232.0    231.0    278.0
# 1 0 days 01:05:29.807000 0 days 01:05:53.935000    227.0    238.0    278.0
# 2 0 days 01:07:07.792000 0 days 01:07:31.941000      NaN    238.0    278.0
# 3 0 days 01:08:45.854000 0 days 01:09:09.917000    228.0    238.0    278.0
# 4 0 days 01:10:23.885000 0 days 01:10:47.952000      NaN    239.0    278.0
#
#    SpeedST IsPersonalBest Compound  TyreLife  FreshTyre             Team  \
# 0    252.0          False     SOFT       4.0      False  Red Bull Racing
# 1    288.0           True     SOFT       5.0      False  Red Bull Racing
# 2    287.0          False     SOFT       6.0      False  Red Bull Racing
# 3    289.0          False     SOFT       7.0      False  Red Bull Racing
# 4    290.0          False     SOFT       8.0      False  Red Bull Racing
#
#             LapStartTime            LapStartDate TrackStatus  Position  \
# 0 0 days 01:02:36.652000 2023-03-05 15:03:38.501          12       1.0
# 1 0 days 01:04:15.902000 2023-03-05 15:05:17.751          12       1.0
# 2 0 days 01:05:53.876000 2023-03-05 15:06:55.725           1       1.0
# 3 0 days 01:07:31.882000 2023-03-05 15:08:33.731           1       1.0
# 4 0 days 01:09:09.858000 2023-03-05 15:10:11.707           1       1.0
#
#    Deleted DeletedReason  FastF1Generated  IsAccurate
# 0    False                          False       False
# 1    False                          False        True
# 2    False                          False        True
# 3    False                          False        True
# 4    False                          False        True

# %%
session.results.head()
# Out:
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 1             1  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 11           11       S PEREZ          PER           perez  Red Bull Racing
# 14           14      F ALONSO          ALO          alonso     Aston Martin
# 55           55       C SAINZ          SAI           sainz          Ferrari
# 44           44    L HAMILTON          HAM        hamilton         Mercedes
#
#    TeamColor        TeamId FirstName    LastName         FullName  \
# 1     3671C6      red_bull       Max  Verstappen   Max Verstappen
# 11    3671C6      red_bull    Sergio       Perez     Sergio Perez
# 14    358C75  aston_martin  Fernando      Alonso  Fernando Alonso
# 55    F91536       ferrari    Carlos       Sainz     Carlos Sainz
# 44    6CD3BF      mercedes     Lewis    Hamilton   Lewis Hamilton
#
#                                           HeadshotUrl CountryCode  Position  \
# 1   https://www.formula1.com/content/dam/fom-websi...         NED       1.0
# 11  https://www.formula1.com/content/dam/fom-websi...         MEX       2.0
# 14  https://www.formula1.com/content/dam/fom-websi...         ESP       3.0
# 55  https://www.formula1.com/content/dam/fom-websi...         ESP       4.0
# 44  https://www.formula1.com/content/dam/fom-websi...         GBR       5.0
#
#    ClassifiedPosition  GridPosition  Q1  Q2  Q3                   Time  \
# 1                   1           1.0 NaT NaT NaT 0 days 01:33:56.736000
# 11                  2           2.0 NaT NaT NaT 0 days 00:00:11.987000
# 14                  3           5.0 NaT NaT NaT 0 days 00:00:38.637000
# 55                  4           4.0 NaT NaT NaT 0 days 00:00:48.052000
# 44                  5           7.0 NaT NaT NaT 0 days 00:00:50.977000
#
#       Status  Points  Laps
# 1   Finished    25.0  57.0
# 11  Finished    18.0  57.0
# 14  Finished    15.0  57.0
# 55  Finished    12.0  57.0
# 44  Finished    10.0  57.0

# %%
session.laps.pick_drivers('VER').get_telemetry()
# Out:
#                          Date            SessionTime DriverAhead  \
# 2     2023-03-05 15:03:38.501 0 days 01:02:36.652000
# 3     2023-03-05 15:03:38.611 0 days 01:02:36.762000
# 4     2023-03-05 15:03:38.686 0 days 01:02:36.837000
# 5     2023-03-05 15:03:38.811 0 days 01:02:36.962000
# 6     2023-03-05 15:03:38.946 0 days 01:02:37.097000
# ...                       ...                    ...         ...
# 42378 2023-03-05 16:37:34.828 0 days 02:36:32.979000
# 42379 2023-03-05 16:37:35.005 0 days 02:36:33.156000
# 42380 2023-03-05 16:37:35.148 0 days 02:36:33.299000
# 42381 2023-03-05 16:37:35.185 0 days 02:36:33.336000
# 42382 2023-03-05 16:37:35.468 0 days 02:36:33.619000
#
#        DistanceToDriverAhead                   Time           RPM       Speed  \
# 2                   0.155556        0 days 00:00:00  10076.374938    0.000000
# 3                   0.155556 0 days 00:00:00.110000  10130.000000    0.000000
# 4                   0.155556 0 days 00:00:00.185000   9993.499884    0.000000
# 5                   0.155556 0 days 00:00:00.310000   9766.000000    0.000000
# 6                   0.155556 0 days 00:00:00.445000   8956.001152    0.964284
# ...                      ...                    ...           ...         ...
# 42378             113.074167 0 days 01:33:56.327000  10525.000000  271.000000
# 42379             113.074167 0 days 01:33:56.504000  10218.568861  263.256253
# 42380             113.074167 0 days 01:33:56.647000   9971.000000  257.000000
# 42381             113.074167 0 days 01:33:56.684000   9861.233523  254.019450
# 42382             113.074167 0 days 01:33:56.967000   9021.666667  231.222222
#
#        nGear  Throttle  Brake  DRS         Source       Distance  \
# 2          1      16.0  False    1  interpolation       0.000194
# 3          1      16.0  False    1            car       0.000000
# 4          1      16.0  False    1            pos      -0.000268
# 5          1      16.0  False    1            car       0.000000
# 6          1      16.0  False    1            pos       0.003325
# ...      ...       ...    ...  ...            ...            ...
# 42378      7       0.0   True    0            car  305405.816944
# 42379      7       0.0   True    0            pos  305418.717638
# 42380      7       0.0   True    0            car  305428.661389
# 42381      7       0.0   True    0            pos  305431.152106
# 42382      7       0.0   True    0  interpolation  305449.085901
#
#        RelativeDistance   Status           X            Y           Z
# 2          6.335301e-10  OnTrack -279.999631  3558.983052 -156.999885
# 3          0.000000e+00  OnTrack -279.999617  3558.982418 -156.999881
# 4         -8.765295e-10  OnTrack -280.000000  3559.000000 -157.000000
# 5          0.000000e+00  OnTrack -280.001327  3559.060983 -157.000413
# 6          1.088396e-08  OnTrack -280.000000  3559.000000 -157.000000
# ...                 ...      ...         ...          ...         ...
# 42378      9.998506e-01  OnTrack -407.146267   742.650673 -158.999991
# 42379      9.998928e-01  OnTrack -400.000000   881.000000 -159.000000
# 42380      9.999254e-01  OnTrack -394.385089   984.164803 -159.000000
# 42381      9.999335e-01  OnTrack -393.000000  1010.000000 -159.000000
# 42382      9.999922e-01  OnTrack -383.626622  1198.840423 -159.000000
#
# [42381 rows x 18 columns]

# %%
event = fastf1.get_event_schedule(2023)

# %%
event.head()
# Out:
#    RoundNumber       Country   Location  \
# 0            0       Bahrain     Sakhir
# 1            1       Bahrain     Sakhir
# 2            2  Saudi Arabia     Jeddah
# 3            3     Australia  Melbourne
# 4            4    Azerbaijan       Baku
#
#                              OfficialEventName  EventDate  \
# 0     FORMULA 1 ARAMCO PRE-SEASON TESTING 2023 2023-02-25
# 1   FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2023 2023-03-05
# 2  FORMULA 1 STC SAUDI ARABIAN GRAND PRIX 2023 2023-03-19
# 3   FORMULA 1 ROLEX AUSTRALIAN GRAND PRIX 2023 2023-04-02
# 4         FORMULA 1 AZERBAIJAN GRAND PRIX 2023 2023-04-30
#
#                   EventName      EventFormat    Session1  \
# 0        Pre-Season Testing          testing  Practice 1
# 1        Bahrain Grand Prix     conventional  Practice 1
# 2  Saudi Arabian Grand Prix     conventional  Practice 1
# 3     Australian Grand Prix     conventional  Practice 1
# 4     Azerbaijan Grand Prix  sprint_shootout  Practice 1
#
#                 Session1Date     Session1DateUtc    Session2  \
# 0  2023-02-23 10:00:00+03:00 2023-02-23 07:00:00  Practice 2
# 1  2023-03-03 14:30:00+03:00 2023-03-03 11:30:00  Practice 2
# 2  2023-03-17 16:30:00+03:00 2023-03-17 13:30:00  Practice 2
# 3  2023-03-31 12:30:00+10:00 2023-03-31 02:30:00  Practice 2
# 4  2023-04-28 13:30:00+04:00 2023-04-28 09:30:00  Qualifying
#
#                 Session2Date     Session2DateUtc         Session3  \
# 0  2023-02-24 10:00:00+03:00 2023-02-24 07:00:00       Practice 3
# 1  2023-03-03 18:00:00+03:00 2023-03-03 15:00:00       Practice 3
# 2  2023-03-17 20:00:00+03:00 2023-03-17 17:00:00       Practice 3
# 3  2023-03-31 16:00:00+10:00 2023-03-31 06:00:00       Practice 3
# 4  2023-04-28 17:00:00+04:00 2023-04-28 13:00:00  Sprint Shootout
#
#                 Session3Date     Session3DateUtc    Session4  \
# 0  2023-02-25 10:00:00+03:00 2023-02-25 07:00:00        None
# 1  2023-03-04 14:30:00+03:00 2023-03-04 11:30:00  Qualifying
# 2  2023-03-18 16:30:00+03:00 2023-03-18 13:30:00  Qualifying
# 3  2023-04-01 12:30:00+10:00 2023-04-01 02:30:00  Qualifying
# 4  2023-04-29 12:30:00+04:00 2023-04-29 08:30:00      Sprint
#
#                 Session4Date     Session4DateUtc Session5  \
# 0                        NaT                 NaT     None
# 1  2023-03-04 18:00:00+03:00 2023-03-04 15:00:00     Race
# 2  2023-03-18 20:00:00+03:00 2023-03-18 17:00:00     Race
# 3  2023-04-01 16:00:00+10:00 2023-04-01 06:00:00     Race
# 4  2023-04-29 17:30:00+04:00 2023-04-29 13:30:00     Race
#
#                 Session5Date     Session5DateUtc  F1ApiSupport
# 0                        NaT                 NaT          True
# 1  2023-03-05 18:00:00+03:00 2023-03-05 15:00:00          True
# 2  2023-03-19 20:00:00+03:00 2023-03-19 17:00:00          True
# 3  2023-04-02 15:00:00+10:00 2023-04-02 05:00:00          True
# 4  2023-04-30 15:00:00+04:00 2023-04-30 11:00:00          True
